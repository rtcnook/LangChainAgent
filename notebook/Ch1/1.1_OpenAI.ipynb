# %% [markdown]
# # OpenAI 调用大模型
#
# ## 0.准备工作
#
# 首先，我们需要安装OpenAI的依赖
# 安装命令：
# ```shell
# uv add openai
# ```

# %% [markdown]
# ## 1.初始化客户端
#
# ### 1.1.硬编码API_KEY

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()

# 创建 OpenAI 客户端
client = OpenAI(
    api_key=os.getenv("SILICONFLOW_API_KEY"),
    base_url=os.getenv("BASE_URL")
)

# %% [markdown]
# ### 1.2. 从环境变量中获取API_KEY

# %% [markdown]
# 读取环境变量需要用到python-dotenv，先安装依赖
# 安装命令：
# ```shell
# uv add python-dotenv
# ```
# 再创建.env文件，并写入api_key
# ```properties
# SILICONFLOW_API_KEY=your-siliconflow-api-key
# ```
# 接着就可以可以从环境变量中获取api_key了

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("SILICONFLOW_API_KEY")
print(api_key)

client = OpenAI(
    api_key=api_key,
    base_url=os.getenv("BASE_URL")
)
# Out:
# your-api-key

# %% [markdown]
# ## 2.访问模型

# %%
print("🚀 正在调用大模型...")
response = client.chat.completions.create(
    model=os.getenv("MODEL_NAME"),
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁?"}
    ],
    stream=False,
    temperature=0.9,
)
print("🚀 成功调用大模型...")
# Out:
# 🚀 正在调用大模型...
# 🚀 成功调用大模型...

# %% [markdown]
# ## 3.获取模型响应结果

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "019e1a9eb4217b5e039e6b90ca2f54b9",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "\n\n👋 你好呀！我是通义千问，是阿里巴巴集团旗下的通义实验室研发的超大规模语言模型。我的主要功能是提供帮助和解答问题，比如回答各种知识性问题、创作文字、编程、逻辑推理等。有什么我可以帮您的吗？😊",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": null,
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null,
#         "reasoning_content": "\n好的，用户问\"你好，你是谁?\"，我需要以友好的AI助教身份回答。首先，要确认用户的需求，他们可能想了解我的身份和功能。作为AI助教，我应该明确说明自己的角色和职责，同时保持亲切的语气。\n\n接下来，我需要确保回答简洁明了，避免使用过于专业的术语。要提到我是由阿里云开发的，属于通义千问系列，这样用户知道是哪个公司的产品。同时，说明我的主要功能是提供帮助和解答问题，这也是用户可能关心的点。\n\n另外，用户的提问方式比较直接，所以回答也应该直接回应。可以加入一些表情符号，比如👋，让回复更生动。还要引导用户提出具体问题，方便他们进一步互动。比如用\"有什么我可以帮您的吗？😊\"来鼓励用户继续提问。\n\n还要注意用户可能的隐藏需求，比如他们可能想测试我的反应或者了解我的能力范围。因此，回答中要体现出我的友好和乐于助人的态度，同时展示我的功能多样性，如回答问题、提供学习资源等。\n\n最后，检查语言是否自然流畅，避免机械化的回答。确保信息准确无误，并且符合阿里巴巴集团的官方描述。这样用户就能清楚明白我的身份和用途，建立信任感。\n"
#       }
#     }
#   ],
#   "created": 1778563069,
#   "model": "Qwen/Qwen3-8B",
#   "object": "chat.completion",
#   "service_tier": null,
#   "system_fingerprint": "",
#   "usage": {
#     "completion_tokens": 329,
#     "prompt_tokens": 26,
#     "total_tokens": 355,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": null,
#       "audio_tokens": null,
#       "reasoning_tokens": 270,
#       "rejected_prediction_tokens": null
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": null,
#       "cached_tokens": 0
#     },
#     "prompt_cache_hit_tokens": 0,
#     "prompt_cache_miss_tokens": 26
#   }
# }

# %%
print(response.choices[0].message.content)
# Out:
# 👋 你好呀！我是通义千问，是阿里巴巴集团旗下的通义实验室研发的超大规模语言模型。我的主要功能是提供帮助和解答问题，比如回答各种知识性问题、创作文字、编程、逻辑推理等。有什么我可以帮您的吗？😊
