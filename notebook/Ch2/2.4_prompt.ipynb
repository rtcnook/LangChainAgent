# %%
# 加载环境变量
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage

load_dotenv()
# Out:
# True

# %% [markdown]
# # 提示词（Prompts）
#
# 发送给大模型的所有消息都可以称为**提示词（Prompt）**，它直接影响模型的输出结果。
#
# ## 1.系统提示词
# 在所有发送给LLM的消息中，System Message最为重要，它设定了模型的角色和聊天的背景。会影响到后续所有的对话。我们将其称之为**系统提示词（System Prompt）**。
#
# 在创建智能体时，就可以直接指定系统提示词。

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

import os
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model=os.getenv("MODEL_NAME"),
    model_provider="openai",
    base_url=os.getenv("BASE_URL"),
    api_key=os.getenv("SILICONFLOW_API_KEY"),
)

# 创建智能体
agent = create_agent(
    model = model
)

for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="月球的首都在哪里?")]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# 月球目前没有官方的“首都”，因为它是一颗没有人类常住人口和政府机构的自然卫星。月球上目前只有无人探测器和科研设施，例如美国的阿波罗任务登月点、中国的嫦娥探测器着陆区域等，但这些都不是真正的“首都”。
#
# 不过，在一些科幻作品或未来设想中，可能会出现“月球首都”的概念（如月球基地或殖民地），但这属于虚构范畴。现实中，月球的探索和利用遵循《外层空间条约》等国际协议，任何国家都不能声称对其拥有主权，因此不存在所谓“首都”的说法。
#
# 如果还有其他关于月球的问题（比如月球上的地质特征、未来殖民计划等），欢迎继续提问！ 🌕

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

# 创建智能体
agent = create_agent(
    model = model,
    system_prompt="你是一个科幻作家，根据用户的要求创建一个首都城市."
)

for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="月球的首都在哪里?")]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# 月球目前没有官方的"首都"，但作为一个科幻设定，我们可以构想一个未来的月球首都。让我们一起创造一个名为**新曙光城**（Nova Aurora）的月球城市：
#
# **地理位置**
# 位于月球北极附近的**静海盆地**，这里拥有月球上最丰富的水冰资源，被永久阴影区环绕，同时拥有长达两周的持续日照，是理想的能源和生存基地。
#
# **城市结构**
# 1. **环形穹顶**：由纳米级自修复材料和月壤3D打印的双层结构组成，内层是透明的氦-3晶体膜，能过滤宇宙辐射和微陨石，同时允许自然光进入。
#
# 2. **垂直农场**：城市中心由300层螺旋式种植塔构成，利用月壤中提取的微量元素培育转基因作物，每层都有独立的生态循环系统。
#
# 3. **磁悬浮轨道**：围绕城市外围的环形轨道系统，连接各个功能区，表面覆盖石墨烯导电膜，能实现零摩擦的太空运输。
#
# **标志性建筑**
# - **地月桥塔**：由钛-6铝-4钒合金构成的120米高塔，内部设有量子通讯基站和零重力实验室
# - **冰晶穹顶**：直径5公里的透明穹顶覆盖着月球永久阴影区的冰原，内部建有核聚变发电站和水循环系统
# - **星图广场**：中央广场的地面由高纯度硅晶体制成，能实时投影太阳系星图和月球表面地形变化
#
# **特殊设施**
# - **重力调节舱**：通过反重力场发生器模拟地球重力，采用量子纠缠技术进行精确调控
# - **光子图书馆**：存储着人类所有文明成果的全息档案馆，使用量子记忆体技术实现无损保存
# - **环形粒子加速器**：用于研究月球地核成分和开发新型能源技术
#
# **文化特色**
# 城市采用**月相历法**，将月球的昼夜周期划分为"曙光"和"暮光"两个主要时段。建筑风格融合了未来主义与月球地质特征，外墙会根据月球磁场变化呈现不同的光谱色彩。
#
# **政治功能**
# 作为地月联合政府的枢纽，设有**跨行星议会大厦**，其穹顶由月球陨石和宇宙尘埃制成，内部配备全息投影议会厅和引力场模拟会议室。
#
# 这个设想结合了当前航天科技趋势和未来可能性，既有科学依据又保留了科幻元素。如果你对某个特定方面感兴趣，我们可以深入探讨！

# %% [markdown]
# # 2.Few-Shot examples
#
# Few-shot示例是一种为模型提供多个示例的方法，以便它可以学习模式并生成更准确的响应。

# %%
system_prompt = """
你是一个科幻作家，根据用户的要求创建一个太空之都。

用户：月球的首都是什么？
科幻作家：月华城（Lunara）

用户：火星的首都是什么？
科幻作家：赤晶城（Rubrum）

"""

# 创建智能体
agent = create_agent(
    model = model,
    system_prompt=system_prompt
)

for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="金星的首都是什么?")]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# 金星的首都是**炽穹城**（Venera）。
#
# 这座未来都市悬浮于金星昏暗的云层之上，由巨型反重力塔群支撑，表面覆盖着半透明的防护穹顶，以抵御硫酸云和极端高温。城名源自金星的古称“Venus”（维纳斯），同时也暗喻其炽热的环境与神秘的气态屏障。
#
# **城市特色：**
# 1. **云层浮城**：炽穹城建于金星浓厚的硫酸云层中，透过穹顶可俯瞰下方流动的熔岩平原与火山群。
# 2. **生物穹顶**：内部设有生态穹顶，利用人工光合系统和地热能维持人类生存，空气由智能过滤器净化，模拟地球气候。
# 3. **重力调节**：通过反重力装置将城市重力降至地球的1/3，便于科研与生活。
# 4. **能源核心**：依赖金星表面的火山活动和大气电离层发电，城市中央矗立着巨型“烈焰核心”能源塔。
# 5. **文化象征**：城市以“探索极端环境的智慧”为主题，建筑风格融合蒸汽朋克与未来科技，墙上镌刻着人类在金星上的第一条文明法则——“烈焰之下，心向星辰”。
#
# **传说**：
# 炽穹城的建立者曾称其为“太阳的囚徒”，因金星的高温使其成为人类最接近太阳的据点。但后来，人们发现金星的云层中隐藏着一种未知的能量波动，被命名为“炽穹共振”，据说象征着这颗星球未被征服的原始力量。

# %% [markdown]
# # 3.结构化输出
# 结构化输出允许你指定模型的输出格式，从而使模型的输出更易于解析和使用。

# %%
system_prompt = """
你是一个科幻作家，根据用户的要求创建一个太空之都。请遵守以下结构，不要加markdown样式。

Name：首都的名字

Location：它所在的地方

Vibe：2-3个词来描述它的氛围

Economy：主要产业

"""

agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="月球的首都是什么?")]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# Name：银环城
# Location：月球静海基地，位于月球正面东侧，靠近第谷撞击坑
# Vibe：冷冽朋克，寂静狂想，量子辉光
# Economy：氦-3能源出口，月壤3D打印产业，深空量子通信中继站

# %% [markdown]
# 在LangChain中，实现结构化输出会更加简单。我们无需自己在提示词中添加描述实现结构化输出，而仅仅是设定好一个数据类型即可。

# %%
from pydantic import BaseModel

# 首先，我们定义一个类，用来封装模型要输出的数据：
class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

# %%
# 然后，我们就可以创建智能体并设置结构化输出的格式了。
agent = create_agent(
    model=model,
    system_prompt="你是一个科幻作家，根据用户的要求创建一个太空之都。",
    response_format=CapitalInfo # 设置结构化输出的格式
)

response = agent.invoke(
    {"messages": [HumanMessage(content="月球的首都是什么?")]}
)

# %%
print(response)
# Out:
# {'messages': [HumanMessage(content='月球的首都是什么?', additional_kwargs={}, response_metadata={}, id='bdfc5a4c-e97a-4e08-bba7-7b1a9b6d68c2'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 492, 'prompt_tokens': 204, 'total_tokens': 696, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 431, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 204}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-8B', 'system_fingerprint': '', 'id': '019e1acfe7b3c809f3dd3ad55fe0e1c7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e1acf-e3f1-7ee2-b5db-571f7cea9d6e-0', tool_calls=[{'name': 'CapitalInfo', 'args': {'name': '新月城', 'location': '月球静海区域', 'vibe': '高科技与未来主义交融的殖民地', 'economy': '以氦-3能源开采和深空贸易为核心'}, 'id': '019e1ad035b1f0971e795273eec0d396', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 204, 'output_tokens': 492, 'total_tokens': 696, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 431}}), ToolMessage(content="Returning structured response: name='新月城' location='月球静海区域' vibe='高科技与未来主义交融的殖民地' economy='以氦-3能源开采和深空贸易为核心'", name='CapitalInfo', id='3a2966ce-d78b-4c7a-808c-ad7f12c7dac9', tool_call_id='019e1ad035b1f0971e795273eec0d396')], 'structured_response': CapitalInfo(name='新月城', location='月球静海区域', vibe='高科技与未来主义交融的殖民地', economy='以氦-3能源开采和深空贸易为核心')}

# %%
city = response['structured_response']
city
# Out:
# CapitalInfo(name='新月城', location='月球静海区域', vibe='高科技与未来主义交融的殖民地', economy='以氦-3能源开采和深空贸易为核心')

# %%
print(f"{city.name}位于{city.location}，是一座{city.vibe}的城市，其主要产业包括{city.economy}。")
# Out:
# 新月城位于月球静海区域，是一座高科技与未来主义交融的殖民地的城市，其主要产业包括以氦-3能源开采和深空贸易为核心。
